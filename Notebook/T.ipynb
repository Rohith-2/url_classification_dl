# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Anirudh Bhaskar\\url_classification_dl\\Notebook'

# %%
os.chdir('../')
os.chdir("FinalDataset\\")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Anirudh Bhaskar\\url_classification_dl\\FinalDataset'
